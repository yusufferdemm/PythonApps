# %%
def flatten_list(liste):
    duz_liste=[]
    duz_liste2=[]
    duz_liste3=[]
    

    for i in liste:
        if type(i) is list :
            for x in i:
                duz_liste.append(x)
            
                
              

        else:
            duz_liste.append(i)
        
    for i in duz_liste:
        if type(i) is list:
            for x in i:
                duz_liste2.append(x)
        else:
            duz_liste2.append(i)
    
    for i in duz_liste2:
        if type(i) is list:
            for x in i:
                duz_liste3.append(x)
        else:
            duz_liste3.append(i)
            
    return duz_liste , duz_liste2 , duz_liste3
    print(duz_liste)
    print(duz_liste2)
    print(duz_liste3)
    


a=[[1,'a',['cat'],2],[[[3]],'dog'],4,5]
flatten_list(a)
# Out:
# ([1, 'a', ['cat'], 2, [[3]], 'dog', 4, 5],
#  [1, 'a', 'cat', 2, [3], 'dog', 4, 5],
#  [1, 'a', 'cat', 2, 3, 'dog', 4, 5])
